# %% [markdown]
# ### **Python Basic and Skills for Programmers:**

# %% [markdown]
# ***First Python Program***
#
# The most basic program when learning Python (or any programming language) is printing "Hello, World!".

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ***Basic Python Program***: Sum of Two Variables

# %%
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %% [markdown]
# # **Using AI to Generate Code**

# %%
x = 10  # Assign value 10 to variable x
y = 0   # Assign value 0 to variable y

# Check if y is not equal to 0 to avoid division by zero
if y != 0:
    result = x / y  # Perform division if safe
    print(result)   # Print the result
else:
    print("Error: Division by zero is not allowed.")  # Error message
    result = None  # Set result to None when division is invalid
# Out:
# Error: Division by zero is not allowed.

# %% [markdown]
# ### ***Factorial Calculation using a Function***
# This version wraps the logic in a function and includes basic input handling.
#
# Prompt : "***please help me generate a python example that uses the for loop and computes factorial a number***"

# %%
def calculate_factorial(num):
    # Check if the number is negative
    if num < 0:
        return "Factorial is not defined for negative numbers."

    # Factorial of 0 is 1 by definition
    elif num == 0:
        return 1

    else:
        fact = 1  # Initialize result

        # Loop from 1 to num (inclusive)
        for i in range(1, num + 1):
            fact *= i  # Multiply current value of fact by i

        return fact  # Return the final factorial value


# Test the function
number = 5  # Define the number to calculate factorial
print(f"The factorial of {number} is {calculate_factorial(number)}")  # Print result
# Out:
# The factorial of 5 is 120

# %% [markdown]
# **# Plotting a Square Function**
#
# This example uses `numpy` to generate data points and `matplotlib` to visualize the function $f(x) = x^2$.
#
# Prompt : "***please help me generate a python example that uses Matplotlib and plots a square function from -10 to 10***"

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate 100 points from -10 to 10
x = np.linspace(-10, 10, 100)
y = x**2

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='y = x^2', color='blue', linewidth=2)

# Add details to the plot
plt.title('Square Function Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### **Compare each element with the current maximum**
# Prompt : "***I have a 1D array of numbers. I want to get the maximum number. Please write Python code to find the maximum number in a list using a for loop.***"

# %%
def find_max(arr):
    if not arr:
        return None  # or raise an error

    max_value = arr[0]

    for element in arr:
        if element > max_value:
            max_value = element

    return max_value

# Test the function
my_array = [10, 24, 5, 32, 18]
print(find_max(my_array))
# Out:
# 32

# %% [markdown]
# # **Add image**
# prompt : "Generate a program to add picture and details it"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the image file (replace with your desired image path)
image_path = '/content/drive/MyDrive/PythonBasic/hinh-nen-may-tinh-anime-cute-1.jpg'

try:
    # Read the image using matplotlib
    img = mpimg.imread(image_path)

    # Create a figure and an axes object
    plt.figure(figsize=(10, 7))

    # Display the image
    plt.imshow(img)

    # Add a title and other details
    plt.title('Displayed Image: IMG_1656.jpeg')
    plt.xlabel('X-axis (pixels)')
    plt.ylabel('Y-axis (pixels)')

    # Remove axis ticks for a cleaner look
    plt.xticks([])
    plt.yticks([])

    # Show the plot
    plt.show()

except FileNotFoundError:
    print(f"Error: The file '{image_path}' was not found. Please check the path.")
except Exception as e:
    print(f"An error occurred: {e}")
